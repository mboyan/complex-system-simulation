# %%
# Import packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import custom modules
import vis_tools as vt
import dla_model as dm
import dla_simulation as ds
import cs_measures as csm

from importlib import reload

# %%
reload(ds)
# Out:
# <module 'dla_simulation' from '/Users/loesbijman/Documents/GitHub/complex-system-simulation/Project/Code/dla_simulation.py'>

# %%
data_vec_angle = pd.read_json('sim_results_drift_vector_angle.json')
data_vec_mag = pd.read_json('sim_results_drift_vector_mag.json')

# %%
ds.plot_environmental_params(data_vec_angle, plot_sun=False, plot_drift_norm = False, plot_drift_angle = True, plot_nutrient_density = False, growth = True, fdr=True, fdc=True, branch=True)
# Out:
# Calculating best minimal value for power law fit
# /Users/loesbijman/anaconda3/envs/my-env/lib/python3.12/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in divide
#   (CDF_diff**2) /
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
