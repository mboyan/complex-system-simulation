# %%
# Import packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import custom modules
import vis_tools as vt
import dla_model as dm
import dla_simulation as ds
import cs_measures as csm

from importlib import reload

# %% [markdown]
# __1. Drift angle__

# %%
reload(ds)
# Out:
# <module 'dla_simulation' from '/Users/loesbijman/Documents/GitHub/complex-system-simulation/Project/Code/dla_simulation.py'>

# %%
data_drift_angle = pd.read_json('sim_results_drift_vector_angle.json')
ds.plot_environmental_results('drift_vec', data_drift_angle, drift_vec_angle = True)
# Out:
# Calculating best minimal value for power law fit
# /Users/loesbijman/anaconda3/envs/my-env/lib/python3.12/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in divide
#   (CDF_diff**2) /
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit

# %% [markdown]
# __2. Drift magnitude__

# %%
data_drift_mag = pd.read_json('sim_results_drift_vector_mag.json')
ds.plot_environmental_results('drift_vec', data_drift_mag)
# Out:
# Calculating best minimal value for power law fit
# /Users/loesbijman/anaconda3/envs/my-env/lib/python3.12/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in divide
#   (CDF_diff**2) /
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit

# %% [markdown]
# __3. Sun vector magnitude__

# %%
data_sun_mag = pd.read_json('results_boyan/sim_results_sun_vector_mag.json')
ds.plot_environmental_results('sun_vec', data_sun_mag)
# Out:
# Calculating best minimal value for power law fit
# /Users/loesbijman/anaconda3/envs/my-env/lib/python3.12/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in divide
#   (CDF_diff**2) /
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit

# %% [markdown]
# __4. Nutrient density__

# %%
data_density = pd.read_json('results_boyan/sim_results_density.json')
ds.plot_environmental_results('particle_density', data_density)
# Out:
# Calculating best minimal value for power law fit
# /Users/loesbijman/anaconda3/envs/my-env/lib/python3.12/site-packages/powerlaw.py:699: RuntimeWarning: invalid value encountered in divide
#   (CDF_diff**2) /
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
